# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('home_fav.csv')

# %%
df.head()
# Out:
#    game_id        date Visitor Team Visitor Pitcher Home Team Home Pitcher  \
# 0        4  2014-03-31          CUB    SAMARDZIJA-R       PIT   FLIRIANO-L
# 1        8  2014-03-31          COL      DELAROSA-L       MIA  JFERNANDZ-R
# 2       10  2014-03-31          KAN      JSHIELDS-R       DET  JVERLANDE-R
# 3       12  2014-03-31          TOR       RDICKEY-R       TAM     DPRICE-L
# 4       13  2014-03-31          MIN      RNOLASCO-R       CWS      CSALE-L
#
#    Open Visitor ML  Close Visitor ML  Home Open ML  Home Close ML   ...    \
# 0              145               170          -165           -190   ...
# 1              140               130          -155           -145   ...
# 2              140               133          -160           -148   ...
# 3              145               144          -165           -164   ...
# 4              145               155          -165           -175   ...
#
#    Visitor RL  Visitor RL Price  Home RL  Home RL Price  final_spread  \
# 0         1.5              -145     -1.5            125             1
# 1         1.5              -175     -1.5            155             9
# 2         1.5              -170     -1.5            150             1
# 3         1.5              -155     -1.5            135             7
# 4         1.5              -145     -1.5            125             2
#
#    payout_ratio   winnings  wager  no_cover  random
# 0      1.689655  16.896552     10       1.0       0
# 1     -1.000000 -10.000000     10       0.0       1
# 2      1.588235  15.882353     10       1.0       0
# 3     -1.000000 -10.000000     10       0.0       0
# 4     -1.000000 -10.000000     10       0.0       0
#
# [5 rows x 22 columns]

# %%
df['Home Pitch Hand'] = df['Home Pitcher'].str.split('-', expand=True)[1]

# %%
df['Visitor Pitch Hand'] = df['Visitor Pitcher'].str.split('-', expand=True)[1]

# %%
df.head()
# Out:
#    game_id        date Visitor Team Visitor Pitcher Home Team Home Pitcher  \
# 0        4  2014-03-31          CUB    SAMARDZIJA-R       PIT   FLIRIANO-L
# 1        8  2014-03-31          COL      DELAROSA-L       MIA  JFERNANDZ-R
# 2       10  2014-03-31          KAN      JSHIELDS-R       DET  JVERLANDE-R
# 3       12  2014-03-31          TOR       RDICKEY-R       TAM     DPRICE-L
# 4       13  2014-03-31          MIN      RNOLASCO-R       CWS      CSALE-L
#
#    Open Visitor ML  Close Visitor ML  Home Open ML  Home Close ML  \
# 0              145               170          -165           -190
# 1              140               130          -155           -145
# 2              140               133          -160           -148
# 3              145               144          -165           -164
# 4              145               155          -165           -175
#
#           ...          Home RL  Home RL Price  final_spread  payout_ratio  \
# 0         ...             -1.5            125             1      1.689655
# 1         ...             -1.5            155             9     -1.000000
# 2         ...             -1.5            150             1      1.588235
# 3         ...             -1.5            135             7     -1.000000
# 4         ...             -1.5            125             2     -1.000000
#
#     winnings  wager  no_cover  random  Home Pitch Hand  Visitor Pitch Hand
# 0  16.896552     10       1.0       0                L                   R
# 1 -10.000000     10       0.0       1                R                   L
# 2  15.882353     10       1.0       0                R                   R
# 3 -10.000000     10       0.0       0                L                   R
# 4 -10.000000     10       0.0       0                L                   R
#
# [5 rows x 24 columns]

# %%
df['winnings'].sum()
# Out:
# 36285.064690993735

# %%
df['wager'].sum()
# Out:
# 65510

# %%
df['Home Pitcher'] = df['Home Pitcher'].str[:-2]

# %%
df['Visitor Pitcher'] = df['Visitor Pitcher'].str[:-2]
